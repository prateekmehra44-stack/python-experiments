# %%
#Question 1:

text = input("Enter string: ")
count = 0

for ch in text:
    if ch.isupper():
        count += 1

print("Capital letters:", count)
# Out:
# Capital letters: 0

# %%
#Question 2:

text = input("Enter string: ")
count = 0

for ch in text.lower():
    if ch in "aeiou":
        count += 1

print("Total vowels:", count)
# Out:
# Total vowels: 0

# %%
#Question 3:

sentence = input("Enter sentence: ")
words = sentence.split()

for w in words:
    print(w)
# Out:
# prateek
# mehra

# %%
#Question 4:

string = input()
substring = input()

count = 0

for i in range(len(string) - len(substring) + 1):
    if string[i:i+len(substring)] == substring:
        count += 1

print(count)
# Out:
# 0

# %%
#Question 5:

text = input("Enter string: ").upper()

for ch in sorted(set(text)):
    if ch.isalpha():
        print(text.count(ch), ch, sep="")
# Out:
# 1P

# %%
#Question 6:

sentence = input("Enter sentence: ")
words = sentence.split()

unique_words = set(words)

print("Unique words count:", len(unique_words))
# Out:
# Unique words count: 1

# %%
#Question 7:

n = int(input("Enter number of fruits: "))

s1 = set()
s2 = set()

print("Enter fruits for set 1:")
for i in range(n):
    s1.add(input())

print("Enter fruits for set 2:")
for i in range(n):
    s2.add(input())

print("Common fruits:", s1 & s2)
print("Only in s1:", s1 - s2)
print("Total fruits count:", len(s1 | s2))
# Out:
# Enter fruits for set 1:
# Enter fruits for set 2:
# Common fruits: {'2'}
# Only in s1: {'1'}
# Total fruits count: 3

# %%
#Question 8:

S1 = {"Red", "yellow", "orange", "blue"}
S2 = {"violet", "blue", "purple"}

print("Union:", S1 | S2)
print("Intersection:", S1 & S2)
print("Only in S1:", S1 - S2)
print("Only in S2:", S2 - S1)
print("Symmetric Difference:", S1 ^ S2)
# Out:
# Union: {'Red', 'orange', 'blue', 'purple', 'violet', 'yellow'}
# Intersection: {'blue'}
# Only in S1: {'Red', 'orange', 'yellow'}
# Only in S2: {'violet', 'purple'}
# Symmetric Difference: {'purple', 'orange', 'Red', 'violet', 'yellow'}
