# %%
#Question 1:

n = int(input("Enter number of values: "))
values = []

for i in range(n):
    num = int(input())
    values.append(num)

for i in range(4):
    print(i, "occurs", values.count(i), "times")
# Out:
# 0 occurs 0 times
# 1 occurs 1 times
# 2 occurs 1 times
# 3 occurs 0 times

# %%
#Question 2:

n = int(input("Enter number of values: "))
numbers = []

for i in range(n):
    num = float(input())
    numbers.append(num)

t = tuple(numbers)

avg = sum(t) / len(t)

print("Average:", avg)
# Out:
# Average: 1.5

# %%
#Question 3:

N = int(input())
scores = list(map(int, input().split()))

unique_scores = sorted(set(scores))

print(unique_scores[-2] if len(unique_scores) >= 2 else "Not enough unique scores")
# Out:
# Not enough unique scores

# %%
#Question 4:

n = int(input("Enter number of persons: "))
data = {}

for i in range(n):
    name = input("Enter name: ")
    city = input("Enter city: ")
    data[name] = city

print("Names:")
for name in data.keys():
    print(name)

print("Cities:")
for city in data.values():
    print(city)

print("Students and Cities:")
for name, city in data.items():
    print(name, "-", city)

city_count = {}
for city in data.values():
    city_count[city] = city_count.get(city, 0) + 1

print("Number of students in each city:")
for city, count in city_count.items():
    print(city, "-", count)
# Out:
# Names:
# prateek ayush
# prateek
# Cities:
# dehradun
# dehradun
# Students and Cities:
# prateek ayush - dehradun
# prateek - dehradun
# Number of students in each city:
# dehradun - 2

# %%
#Question 5:

n = int(input("Enter number of movies: "))
movies = {}

for i in range(n):
    name = input("Movie name: ")
    year = int(input("Year: "))
    director = input("Director: ")
    cost = float(input("Production cost: "))
    collection = float(input("Collection made: "))
    
    movies[name] = {
        "year": year,
        "director": director,
        "cost": cost,
        "collection": collection
    }

print("All Movie Details:")
for name, details in movies.items():
    print(name, details)

print("Movies released before 2015:")
for name, details in movies.items():
    if details["year"] < 2015:
        print(name)

print("Movies that made profit:")
for name, details in movies.items():
    if details["collection"] > details["cost"]:
        print(name)

director_name = input("Enter director name to search: ")

print("Movies by", director_name, ":")
for name, details in movies.items():
    if details["director"] == director_name:
        print(name)
# Out:
# All Movie Details:
# world of dragons {'year': 2015, 'director': 'robert frost', 'cost': 100000.0, 'collection': 1000000.0}
# Movies released before 2015:
# Movies that made profit:
# world of dragons
# Movies by robert frost :
# world of dragons
